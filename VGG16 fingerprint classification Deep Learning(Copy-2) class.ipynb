# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG16
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
fingertype = {
    'real': '01',
    'altered': '02',
}

# %%
dataset="C://Users//tatba//OneDrive//Desktop//Dataset//Fingerprintscan"

# %%
# Image parameters
img_height, img_width = 128, 128

# %%
# Load images and labels from filenames
def load_data(path):
    images = []
    labels = []
    for filename in os.listdir(path):
        if filename.endswith('.BMP'):
            # Load image manually using cv2
            img_path = os.path.join(path, filename)
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            img = cv2.resize(img, (img_width, img_height))
            img_array = img / 255.0  # Normalize
            images.append(img_array)
            # Extract emotion from filename (3rd element in the filename)
            finger_code = filename.split('-')[0]
            finger_label = fingertype[finger_code]
            labels.append(finger_code)
    return np.array(images), np.array(labels)

# %%
# Load the dataset
X, y = load_data(dataset)

# %%
# Encode labels as integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# Convert labels to categorical (one-hot encoding)
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=2)

# %%
# Define a simple CNN model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(2, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 16, 16, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,846,786 (64.27 MB)
#  Trainable params: 16,846,018 (64.26 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
loss='binary_crossentropy',
metrics=['accuracy'])

# %%
history = model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=50,
    batch_size=16
)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.5456 - loss: 0.8715 - val_accuracy: 0.4357 - val_loss: 17.7941
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.6551 - loss: 0.7572 - val_accuracy: 0.4357 - val_loss: 8.7991
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7218 - loss: 0.6224 - val_accuracy: 0.4357 - val_loss: 5.3847
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7216 - loss: 0.6358 - val_accuracy: 0.4357 - val_loss: 6.5012
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.7274 - loss: 0.6504 - val_accuracy: 0.4357 - val_loss: 5.2717
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.7741 - loss: 0.5529 - val_accuracy: 0.4357 - val_loss: 4300.3882
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7426 - loss: 0.5789 - val_accuracy: 0.4357 - val_loss: 7.0930
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7479 - loss: 0.5760 - val_accuracy: 0.4357 - val_loss: 9.2636
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7448 - loss: 0.5796 - val_accuracy: 0.4357 - val_loss: 3.6718
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8020 - loss: 0.4920 - val_accuracy: 0.4643 - val_loss: 3.7385
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7769 - loss: 0.5334 - val_accuracy: 0.5000 - val_loss: 3.4441
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7580 - loss: 0.5547 - val_accuracy: 0.4357 - val_loss: 39005.3203
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.7562 - loss: 0.5458 - val_accuracy: 0.4357 - val_loss: 16.2612
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7864 - loss: 0.5341 - val_accuracy: 0.4929 - val_loss: 1.6423
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7914 - loss: 0.4595 - val_accuracy: 0.5429 - val_loss: 2.2287
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7930 - loss: 0.5130 - val_accuracy: 0.4357 - val_loss: 14.3664
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7959 - loss: 0.4658 - val_accuracy: 0.4357 - val_loss: 6.7064
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8141 - loss: 0.4542 - val_accuracy: 0.4500 - val_loss: 5.3943
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8023 - loss: 0.4705 - val_accuracy: 0.5071 - val_loss: 2.5334
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8331 - loss: 0.4230 - val_accuracy: 0.6786 - val_loss: 0.7333
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8125 - loss: 0.4336 - val_accuracy: 0.5429 - val_loss: 2.0053
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8009 - loss: 0.4510 - val_accuracy: 0.7643 - val_loss: 0.6959
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7897 - loss: 0.4916 - val_accuracy: 0.4500 - val_loss: 1.7393
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8317 - loss: 0.4020 - val_accuracy: 0.4714 - val_loss: 2.5786
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8396 - loss: 0.4510 - val_accuracy: 0.5929 - val_loss: 1.4116
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8584 - loss: 0.4127 - val_accuracy: 0.6357 - val_loss: 0.6483
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.8227 - loss: 0.4231 - val_accuracy: 0.4357 - val_loss: 4.1828
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8129 - loss: 0.4540 - val_accuracy: 0.5643 - val_loss: 14.6121
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8619 - loss: 0.3662 - val_accuracy: 0.7143 - val_loss: 0.8574
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7923 - loss: 0.4567 - val_accuracy: 0.4500 - val_loss: 5.0617
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8343 - loss: 0.4312 - val_accuracy: 0.5357 - val_loss: 0.9985
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8262 - loss: 0.3953 - val_accuracy: 0.4643 - val_loss: 3.5297
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8141 - loss: 0.4297 - val_accuracy: 0.4357 - val_loss: 5.7097
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.7833 - loss: 0.4588 - val_accuracy: 0.4357 - val_loss: 18.3836
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8239 - loss: 0.4273 - val_accuracy: 0.4929 - val_loss: 2.6813
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8282 - loss: 0.3918 - val_accuracy: 0.4571 - val_loss: 2.2122
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8266 - loss: 0.4170 - val_accuracy: 0.5286 - val_loss: 1.0359
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8412 - loss: 0.3740 - val_accuracy: 0.5357 - val_loss: 1.3073
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.7940 - loss: 0.4698 - val_accuracy: 0.5714 - val_loss: 0.9275
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8570 - loss: 0.3846 - val_accuracy: 0.5714 - val_loss: 0.8731
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8733 - loss: 0.3464 - val_accuracy: 0.5500 - val_loss: 1.8735
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.8167 - loss: 0.4189 - val_accuracy: 0.5071 - val_loss: 1.9417
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8655 - loss: 0.3914 - val_accuracy: 0.4571 - val_loss: 1.6232
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.8139 - loss: 0.4686 - val_accuracy: 0.7071 - val_loss: 1.0247
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.8534 - loss: 0.3564 - val_accuracy: 0.5714 - val_loss: 1.1444
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8225 - loss: 0.3972 - val_accuracy: 0.4357 - val_loss: 4.8465
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8482 - loss: 0.4104 - val_accuracy: 0.4357 - val_loss: 2.5579
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.8062 - loss: 0.4323 - val_accuracy: 0.5214 - val_loss: 2.1911
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8187 - loss: 0.3733 - val_accuracy: 0.5929 - val_loss: 0.8488
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8432 - loss: 0.3790 - val_accuracy: 0.4429 - val_loss: 1.5911

# %%
# Plot training & validation accuracy/loss
def plot_accuracy_loss(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc,color='blue', label='Training accuracy')
    plt.plot(epochs, val_acc,color='yellow', label='Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss,color='blue', label='Training loss')
    plt.plot(epochs, val_loss,color='yellow', label='Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_accuracy_loss(history)

# %%
# Get predictions
Y_pred = model.predict(X_val)
y_pred = np.argmax(Y_pred, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 619ms/step

# %%
# Confusion matrix and classification report
clr = classification_report(y_val, y_pred, target_names=fingertype)
print("Classification Report")
print(clr)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
labels = list(fingertype.values())
print("Confusion Matrix")
print(cm) 
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         real       1.00      0.01      0.03        79
#      altered       0.44      1.00      0.61        61
#
#     accuracy                           0.44       140
#    macro avg       0.72      0.51      0.32       140
# weighted avg       0.76      0.44      0.28       140
#
# Confusion Matrix
# [[ 1 78]
#  [ 0 61]]

# %%
# Binarize labels for ROC-AUC
n_classes = len(labels)
y_val_bin = tf.keras.utils.to_categorical(y_val, num_classes=n_classes)
y_pred_bin = tf.keras.utils.to_categorical(y_pred, num_classes=n_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], Y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='best')
plt.show()

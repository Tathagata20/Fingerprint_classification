# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import VGG19
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
fingertype = {
    'real': '01',
    'altered': '02',
}

# %%
dataset="C://Users//tatba//OneDrive//Desktop//Dataset//Fingerprintscan"

# %%
# Image parameters
img_height, img_width = 128, 128

# %%
# Load images and labels from filenames
def load_data(path):
    images = []
    labels = []
    for filename in os.listdir(path):
        if filename.endswith('.BMP'):
            # Load image manually using cv2
            img_path = os.path.join(path, filename)
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
            img = cv2.resize(img, (img_width, img_height))
            img_array = img / 255.0  # Normalize
            images.append(img_array)
            # Extract emotion from filename (3rd element in the filename)
            finger_code = filename.split('-')[0]
            finger_label = fingertype[finger_code]
            labels.append(finger_code)
    return np.array(images), np.array(labels)

# %%
# Load the dataset
X, y = load_data(dataset)

# %%
# Encode labels as integers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# Convert labels to categorical (one-hot encoding)
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_val_cat = tf.keras.utils.to_categorical(y_val, num_classes=2)

# %%
# Define a simple CNN model
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
output = Dense(2, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 128, 128, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 64, 64, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv4 (Conv2D)                │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 16, 16, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv4 (Conv2D)                │ (None, 16, 16, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 8, 8, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv4 (Conv2D)                │ (None, 8, 8, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       2,097,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,156,482 (84.52 MB)
#  Trainable params: 22,155,714 (84.52 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# Compile the model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
loss='binary_crossentropy',
metrics=['accuracy'])

# %%
history = model.fit(
    X_train,
    y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=50,
    batch_size=16
)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.5446 - loss: 0.9647 - val_accuracy: 0.4357 - val_loss: 49.0729
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.6100 - loss: 0.8314 - val_accuracy: 0.4357 - val_loss: 48752.4141
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7043 - loss: 0.6842 - val_accuracy: 0.4357 - val_loss: 6.2364
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7090 - loss: 0.6711 - val_accuracy: 0.4357 - val_loss: 5.2884
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.6899 - loss: 0.6733 - val_accuracy: 0.4357 - val_loss: 4.2947
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7420 - loss: 0.6267 - val_accuracy: 0.4357 - val_loss: 5.1053
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.6991 - loss: 0.5944 - val_accuracy: 0.5000 - val_loss: 2.8985
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7297 - loss: 0.5821 - val_accuracy: 0.4714 - val_loss: 3.2772
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7595 - loss: 0.5635 - val_accuracy: 0.4357 - val_loss: 4.6799
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7790 - loss: 0.5447 - val_accuracy: 0.4857 - val_loss: 2.9077
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7875 - loss: 0.5000 - val_accuracy: 0.4357 - val_loss: 5.1137
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.7844 - loss: 0.5089 - val_accuracy: 0.4571 - val_loss: 3.2464
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.7683 - loss: 0.5553 - val_accuracy: 0.4857 - val_loss: 2.1751
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7724 - loss: 0.5519 - val_accuracy: 0.4429 - val_loss: 5.3996
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7966 - loss: 0.4682 - val_accuracy: 0.5143 - val_loss: 2.8781
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7850 - loss: 0.4723 - val_accuracy: 0.4857 - val_loss: 2.8400
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7839 - loss: 0.5003 - val_accuracy: 0.5429 - val_loss: 336114496.0000
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7879 - loss: 0.4952 - val_accuracy: 0.4357 - val_loss: 7.1215
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7564 - loss: 0.5618 - val_accuracy: 0.4357 - val_loss: 14.7677
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7949 - loss: 0.5328 - val_accuracy: 0.4357 - val_loss: 6.4885
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7624 - loss: 0.5011 - val_accuracy: 0.4357 - val_loss: 8.9403
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8095 - loss: 0.4505 - val_accuracy: 0.5429 - val_loss: 2.0784
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8037 - loss: 0.4890 - val_accuracy: 0.5357 - val_loss: 1.4714
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8357 - loss: 0.4178 - val_accuracy: 0.4643 - val_loss: 3.5753
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7807 - loss: 0.5467 - val_accuracy: 0.4643 - val_loss: 3.5925
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7848 - loss: 0.4783 - val_accuracy: 0.5000 - val_loss: 2.5391
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.7943 - loss: 0.4292 - val_accuracy: 0.5643 - val_loss: 1.3566
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7899 - loss: 0.4947 - val_accuracy: 0.4357 - val_loss: 6.1679
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8216 - loss: 0.4432 - val_accuracy: 0.4214 - val_loss: 3183065.2500
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8079 - loss: 0.4149 - val_accuracy: 0.5643 - val_loss: 3.9011
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.8018 - loss: 0.4552 - val_accuracy: 0.4357 - val_loss: 4.9205
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.8049 - loss: 0.4387 - val_accuracy: 0.4429 - val_loss: 6.7841
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8565 - loss: 0.3718 - val_accuracy: 0.4357 - val_loss: 14.1884
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8184 - loss: 0.4151 - val_accuracy: 0.4714 - val_loss: 3.4621
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7989 - loss: 0.4388 - val_accuracy: 0.5500 - val_loss: 0.9106
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8198 - loss: 0.3904 - val_accuracy: 0.6500 - val_loss: 0.6552
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - accuracy: 0.8819 - loss: 0.3554 - val_accuracy: 0.4357 - val_loss: 4.1010
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7769 - loss: 0.4800 - val_accuracy: 0.4357 - val_loss: 7.9163
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8195 - loss: 0.4141 - val_accuracy: 0.5571 - val_loss: 2.1567
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.8644 - loss: 0.3884 - val_accuracy: 0.6357 - val_loss: 0.6593
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 594s 17s/step - accuracy: 0.8460 - loss: 0.3719 - val_accuracy: 0.5357 - val_loss: 1.0995
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.8460 - loss: 0.3734 - val_accuracy: 0.8357 - val_loss: 0.4615
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8706 - loss: 0.3513 - val_accuracy: 0.4357 - val_loss: 11.6589
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8464 - loss: 0.3785 - val_accuracy: 0.4357 - val_loss: 4.8224
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8490 - loss: 0.3623 - val_accuracy: 0.4357 - val_loss: 25.8395
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8261 - loss: 0.4136 - val_accuracy: 0.4357 - val_loss: 12.1957
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8616 - loss: 0.3514 - val_accuracy: 0.4357 - val_loss: 13.2628
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8264 - loss: 0.4432 - val_accuracy: 0.4357 - val_loss: 119.1174
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.8815 - loss: 0.3445 - val_accuracy: 0.4429 - val_loss: 4.5964
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.8332 - loss: 0.3969 - val_accuracy: 0.4357 - val_loss: 19.4442

# %%
# Plot training & validation accuracy/loss
def plot_accuracy_loss(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc,color='blue', label='Training accuracy')
    plt.plot(epochs, val_acc,color='yellow', label='Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss,color='blue', label='Training loss')
    plt.plot(epochs, val_loss,color='yellow', label='Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

plot_accuracy_loss(history)

# %%
# Get predictions
Y_pred = model.predict(X_val)
y_pred = np.argmax(Y_pred, axis=1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 788ms/step

# %%
# Confusion matrix and classification report
clr = classification_report(y_val, y_pred, target_names=fingertype)
print("Classification Report")
print(clr)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
labels = list(fingertype.values())
print("Confusion Matrix")
print(cm) 
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#         real       0.00      0.00      0.00        79
#      altered       0.44      1.00      0.61        61
#
#     accuracy                           0.44       140
#    macro avg       0.22      0.50      0.30       140
# weighted avg       0.19      0.44      0.26       140
#
# Confusion Matrix
# [[ 0 79]
#  [ 0 61]]
# C:\Users\tatba\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\tatba\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\tatba\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Binarize labels for ROC-AUC
n_classes = len(labels)
y_val_bin = tf.keras.utils.to_categorical(y_val, num_classes=n_classes)
y_pred_bin = tf.keras.utils.to_categorical(y_pred, num_classes=n_classes)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], Y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='best')
plt.show()
